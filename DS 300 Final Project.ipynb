# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_phishing.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11430 entries, 0 to 11429
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         11430 non-null  object
#  1   length_url                  11430 non-null  int64
#  2   length_hostname             11430 non-null  int64
#  3   ip                          11430 non-null  int64
#  4   nb_dots                     11430 non-null  int64
#  5   nb_hyphens                  11430 non-null  int64
#  6   nb_at                       11430 non-null  int64
#  7   nb_qm                       11430 non-null  int64
#  8   nb_and                      11430 non-null  int64
#  9   nb_or                       11430 non-null  int64
#  10  nb_eq                       11430 non-null  int64
#  11  nb_underscore               11430 non-null  int64
#  12  nb_tilde                    11430 non-null  int64
# ...

# %%
df.describe()
# Out:
#          length_url  length_hostname            ip       nb_dots  \
# count  11430.000000     11430.000000  11430.000000  11430.000000
# mean      61.126684        21.090289      0.150569      2.480752
# std       55.297318        10.777171      0.357644      1.369686
# min       12.000000         4.000000      0.000000      1.000000
# 25%       33.000000        15.000000      0.000000      2.000000
# 50%       47.000000        19.000000      0.000000      2.000000
# 75%       71.000000        24.000000      0.000000      3.000000
# max     1641.000000       214.000000      1.000000     24.000000
#
#          nb_hyphens         nb_at         nb_qm        nb_and    nb_or  \
# count  11430.000000  11430.000000  11430.000000  11430.000000  11430.0
# mean       0.997550      0.022222      0.141207      0.162292      0.0
# std        2.087087      0.155500      0.364456      0.821337      0.0
# min        0.000000      0.000000      0.000000      0.000000      0.0
# ...

# %%
df.head()
# Out:
#                                                  url  length_url  \
# 0              http://www.crestonwood.com/router.php          37
# 1  http://shadetreetechnology.com/V4/validation/a...          77
# 2  https://support-appleld.com.secureupdate.duila...         126
# 3                                 http://rgipt.ac.in          18
# 4  http://www.iracing.com/tracks/gateway-motorspo...          55
#
#    length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  ...  \
# 0               19   0        3           0      0      0       0      0  ...
# 1               23   1        1           0      0      0       0      0  ...
# 2               50   1        4           1      0      1       2      0  ...
# 3               11   0        2           0      0      0       0      0  ...
# 4               15   0        2           2      0      0       0      0  ...
#
#    domain_in_title  domain_with_copyright  whois_registered_domain  \
# ...

# %%
df.isna().sum()
# Out:
# url                0
# length_url         0
# length_hostname    0
# ip                 0
# nb_dots            0
#                   ..
# web_traffic        0
# dns_record         0
# google_index       0
# page_rank          0
# status             0
# Length: 89, dtype: int64

# %%
df['status'].value_counts()
# Out:
# phishing      5715
# legitimate    5715
# Name: status, dtype: int64

# %%
df['page_rank'].value_counts()
# Out:
# 0     2666
# 5     2057
# 2     1553
# 4     1380
# 3     1232
# 1      735
# 6      727
# 7      509
# 10     269
# 8      262
# 9       40
# Name: page_rank, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,5))
plt.title("Page rank colored by phishing status", fontsize=17)

sns.countplot(data = df, x = 'page_rank', hue = 'status')
plt.xlabel("Page Rank", fontsize=15)
# Out:
# Text(0.5, 0, 'Page Rank')

# %%
sns.countplot(data = df, x = 'status')
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
df.drop('url', axis='columns', inplace=True)
useless_cols = []

for col in df:
    if len(df[col].value_counts()) == 1:
        useless_cols.append(col)
        
print(useless_cols)
# Out:
# ['nb_or', 'ratio_nullHyperlinks', 'ratio_intRedirection', 'ratio_intErrors', 'submit_email', 'sfh']

# %%
df.drop(useless_cols, axis='columns', inplace=True)

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
ss = StandardScaler()
le = LabelEncoder()

df['status'] = le.fit_transform(df['status'])
df_scaled = pd.DataFrame(ss.fit_transform(df), columns=df.columns)

x = df_scaled.drop('status', axis='columns')
y = df_scaled['status']

# %%
plt.figure(figsize=(35,35))

sns.heatmap(data = df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
corr_mat = df.corr(method='pearson')
  
sorted_mat = corr_mat.unstack().sort_values()

corr_mat
# Out:
#                  length_url  length_hostname        ip   nb_dots  nb_hyphens  \
# length_url         1.000000         0.223025  0.453961  0.443589    0.399564
# length_hostname    0.223025         1.000000  0.252013  0.408956    0.057702
# ip                 0.453961         0.252013  1.000000  0.288398    0.109860
# nb_dots            0.443589         0.408956  0.288398  1.000000    0.045099
# nb_hyphens         0.399564         0.057702  0.109860  0.045099    1.000000
# ...                     ...              ...       ...       ...         ...
# web_traffic        0.072205         0.163238  0.167930  0.087969   -0.041464
# dns_record         0.023357        -0.023344  0.127823  0.126659   -0.031477
# google_index       0.236395         0.213990  0.270743  0.209616   -0.018828
# page_rank         -0.102582        -0.159342 -0.218968 -0.097312    0.104341
# status             0.248580         0.238322  0.321698  0.207029   -0.100107
#
# ...

# %%
rows, cols = df.shape
flds = list(df.columns)
corr = df.corr().values

for i in range(cols):
    for j in range(i+1, cols):
        if corr[i,j] > 0.7:
            print(flds[i], ' ', flds[j], ' ', corr[i,j])
# Out:
# length_url   length_words_raw   0.7947099649225181
# ip   ratio_digits_url   0.7689060308671765
# nb_qm   nb_eq   0.7317349421484434
# nb_and   nb_eq   0.9064043216805588
# ratio_digits_host   abnormal_subdomain   0.7027723669081383
# shortest_word_host   avg_word_host   0.8000139779240063
# longest_words_raw   longest_word_path   0.9685027593654566
# longest_words_raw   avg_words_raw   0.7847534620059231
# longest_words_raw   avg_word_path   0.7253436929955664
# longest_word_host   avg_word_host   0.8163134513578
# longest_word_path   avg_words_raw   0.7019143510026277
# longest_word_path   avg_word_path   0.7911975411767534
# avg_words_raw   avg_word_path   0.7298172523450611
# ratio_intHyperlinks   links_in_tags   0.7993736394477551
# google_index   status   0.7311708381263218
